# %% [markdown]
# # Import package

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load data

# %%
data_path = os.path.join('..', 'data', 'train.csv')

data = pd.read_csv(data_path)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_25020\1615417973.py:3: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_path)

# %% [markdown]
# # Data exploration

# %%
data.head(3)
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
data['Num_of_Delayed_Payment'].unique()
# Out:
# array(['7', nan, '4', '8_', '6', '1', '-1', '3_', '0', '8', '5', '3', '9',
#        '12', '15', '17', '10', '2', '2_', '11', '14', '20', '22', '13',
#        '13_', '14_', '16', '12_', '18', '19', '23', '24', '21', '3318',
#        '3083', '22_', '1338', '4_', '26', '11_', '3104', '21_', '25',
#        '10_', '183_', '9_', '1106', '834', '19_', '24_', '17_', '23_',
#        '2672', '20_', '2008', '-3', '538', '6_', '1_', '16_', '27', '-2',
#        '3478', '2420', '15_', '707', '708', '26_', '18_', '3815', '28',
#        '5_', '1867', '2250', '1463', '25_', '7_', '4126', '2882', '1941',
#        '2655', '2628', '132', '3069', '306', '0_', '3539', '3684', '1823',
#        '4128', '1946', '827', '2297', '2566', '904', '182', '929', '3568',
#        '2503', '1552', '2812', '1697', '3764', '851', '3905', '923', '88',
#        '1668', '3253', '808', '2689', '3858', '642', '3457', '1402',
#        '1732', '3154', '847', '3037', '2204', '3103', '1063', '2056',
# ...

# %% [markdown]
# # Plotting

# %%
sns.countplot(data=data, x='Credit_Score', palette='viridis')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_25020\1504575305.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Credit_Score', palette='viridis')
# <Axes: xlabel='Credit_Score', ylabel='count'>

# %%
sns.displot(data['Monthly_Inhand_Salary'])

# %%
sns.displot(data['Interest_Rate'])

# %%
sns.displot(data['Delay_from_due_date'])
